# %% [markdown]
# ### Merge and clean datasets

# %%
import pandas as pd

# %% [markdown]
# #### Load the dataframes

# %%
def load_data():
    data = pd.read_excel('data/data.xlsx')
    return data

# %%
df = load_data()

# %%
df
# Out:
#                      ? (Question Mark) & The Mysterians  \
# 0                       "Boyan" Russian Folk Orchestra*
# 1                                             "D" Train
# 2                            "Salad Days" Original Cast
# 3                                                 (pH)2
# 4                                              10 c.c.*
# ...                                                 ...
# 6228                                     П. Чайковский*
# 6229  П. Чайковский* = P. Tchaikovsky*, Государствен...
# 6230                                    Русский Сувенир
# 6231  Сергей Прокофьев* - Ицхак Перльман*, BBC Symph...
# 6232                                      Шаукат Амиров
#
#                                             96 Tears  Vinyl 45  1966  \
# 0                                            Barynya  Vinyl 33  1980
# 1                              You're The One For Me  Vinyl 33  1988
# 2             Selection Of The Songs From Salad Days  Vinyl 33  1954
# 3                                           Jeronymo  Vinyl 33  1989
# 4                                         Silly Love  Vinyl 45  1974
# ...                                              ...       ...   ...
# 6228                   Симфония № 6 / Symphony No. 6  Vinyl 33  1988
# 6229                                        Литургия  Vinyl 33  1990
# 6230                                Russian Souvenir  Vinyl 45  1982
# 6231  Concertos For Violin And Orchestra No. 1 And 2  Vinyl 33  1983
# 6232                                       Балалайка  Vinyl 33  1990
#
#             Rock Germany       19 252 AT                   Ariola Unnamed: 8  \
# 0           Folk    USSR  C20---12949-50                  Мелодия        NaN
# 1          Disco  Canada       SPEC 1237          Prelude Records        NaN
# 2     Soundtrack      UK        MG 20004                   Oriole        NaN
# 3            Pop  Greece           10350  Music Box International        NaN
# 4       Pop Rock      UK           UK 77               UK Records        NaN
# ...          ...     ...             ...                      ...        ...
# 6228   Classical    USSR     C10-16225-6                  Мелодия        NaN
# 6229   Classical    USSR   А10 00637 005                  Мелодия        NaN
# 6230        Folk    USSR  С92 — 17619-20                  Мелодия        NaN
# 6231   Classical    USSR   A10 00021 002                  Мелодия        NaN
# 6232   Classical    USSR   С20 29659 002                  Мелодия        NaN
#
#      https://www.discogs.com/release/2271800--Question-Mark-The-Mysterians-96-Tears  \
# 0     https://www.discogs.com/release/4777841-Boyan-...
# 1     https://www.discogs.com/release/1814321-D-Trai...
# 2     https://www.discogs.com/release/3757702-Salad-...
# 3     https://www.discogs.com/release/5132510-pH2-Je...
# 4     https://www.discogs.com/release/7486955-10-cc-...
# ...                                                 ...
# 6228  https://www.discogs.com/release/14425596-%D0%9...
# 6229  https://www.discogs.com/release/5337445-%D0%9F...
# 6230  https://www.discogs.com/release/5019118-%D0%A0...
# 6231  https://www.discogs.com/release/3948458-%D0%A1...
# 6232  https://www.discogs.com/release/9796516-%D0%A8...
#
#                                             Unnamed: 10 Unnamed: 11
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 6228                                                NaN         NaN
# 6229                                                NaN         NaN
# 6230  https://www.discogs.com/release/5019118-%D0%A0...         NaN
# 6231  https://www.discogs.com/release/3948458-%D0%A1...         NaN
# 6232  https://www.discogs.com/release/9796516-%D0%A8...         NaN
#
# [6233 rows x 12 columns]

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Drop unused columns and replace NAs

# %%
df.drop('CAT#', axis=1 , inplace=True)
df.drop(list(df.filter(regex = 'Unnamed')), axis = 1, inplace = True)

# %%
def trim_all_columns(df):
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)
cols = [ 'Title','Artist','Type','Genre','Released', 'Country','Label']
df = trim_all_columns(df).reindex(columns=cols)

# %%
df['Released'] = df['Released'].fillna(0).astype(int)

# %%
df
# Out:
#                                 Title  \
# 0                            96 Tears
# 1               You're The One For Me
# 2                      Play The Blues
# 3                   The Soul Of Spain
# 4     10 CC's Greatest Hits 1972-1978
# ...                               ...
# 3629                          Romance
# 3630          Classics By Candlelight
# 3631                     Alte Märsche
# 3632               The Best Of ZZ Top
# 3633                           Камино
#
#                                                Artist      Type  \
# 0                  ? (Question Mark) & The Mysterians  Vinyl 45
# 1                                           "D" Train  Vinyl 33
# 2                                         101 Strings  Vinyl 33
# 3                                         101 Strings  Vinyl 33
# 4                                                10cc  Vinyl 33
# ...                                               ...       ...
# 3629                                           Zamfir  Vinyl 33
# 3630                      Zamfir / van Hoof Orchestra  Vinyl 33
# 3631  Zentrales Orchester Des Ministeriums Des Innern  Vinyl 33
# 3632                                           ZZ Top  Vinyl 33
# 3633                                     Лили Иванова  Vinyl 33
#
#                Genre  Released   Country                      Label
# 0               Rock      1966   Germany                     Ariola
# 1              Disco      1988    Canada            Prelude Records
# 2              Blues      1958       USA  Pye Golden Guinea Records
# 3          Classical      1959        UK  Pye Golden Guinea Records
# 4           Art Rock      1979    Greece                    Mercury
# ...              ...       ...       ...                        ...
# 3629  Easy Listening      1982    Greece                    Philips
# 3630  Easy Listening      1980        UK                    Philips
# 3631         Marches      1966       GDR                     ETERNA
# 3632      Blues Rock      1977    Greece                Warner Bros
# 3633        Schlager      1969  Bulgaria                  Балкантон
#
# [3634 rows x 7 columns]

# %%
df.head()
# Out:
#                              Title                              Artist  \
# 0                         96 Tears  ? (Question Mark) & The Mysterians
# 1            You're The One For Me                           "D" Train
# 2                   Play The Blues                         101 Strings
# 3                The Soul Of Spain                         101 Strings
# 4  10 CC's Greatest Hits 1972-1978                                10cc
#
#        Type      Genre  Released  Country                      Label
# 0  Vinyl 45       Rock      1966  Germany                     Ariola
# 1  Vinyl 33      Disco      1988   Canada            Prelude Records
# 2  Vinyl 33      Blues      1958      USA  Pye Golden Guinea Records
# 3  Vinyl 33  Classical      1959       UK  Pye Golden Guinea Records
# 4  Vinyl 33   Art Rock      1979   Greece                    Mercury

# %%
df.shape
# Out:
# (3634, 7)

# %% [markdown]
# #### Check for duplicated rows and drop

# %%
df.duplicated(subset=['Title','Artist', 'Genre', 'Released', 'Country',
 'Label','Type']).sum()
# Out:
# 3

# %%
dups = df.loc[df.duplicated(subset=['Title','Artist', 'Genre',
                                           'Released', 'Country',
                                           'Label','Type'],keep=False), :]

# %%
dups
# Out:
#                                Title         Artist      Type      Genre  \
# 1445  Mad, Bad And Dangerous To Know  Dead Or Alive  Vinyl 33  Synth-pop
# 1446  Mad, Bad And Dangerous To Know  Dead Or Alive  Vinyl 33  Synth-pop
# 1447                 Out Of The Blue  Debbie Gibson  Vinyl 33  Synth-pop
# 1448                 Out Of The Blue  Debbie Gibson  Vinyl 33  Synth-pop
# 3282           Η Ελλάδα Τραγουδάει..        Various  Vinyl 33       Folk
# 3283           Η Ελλάδα Τραγουδάει..        Various  Vinyl 33       Folk
#
#       Released Country     Label
# 1445      1986  Greece      Epic
# 1446      1986  Greece      Epic
# 1447      1987  Greece  Atlantic
# 1448      1987  Greece  Atlantic
# 3282      1979  Greece  Columbia
# 3283      1979  Greece  Columbia

# %% [markdown]
# > keep duplicates to certify errors

# %%
df.drop_duplicates(subset=['Title','Artist', 'Genre',
                                  'Released', 'Country',
                                  'Label','Type'], keep='first', inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.shape
# Out:
# (3631, 7)

# %%
df
# Out:
#                                 Title  \
# 0                            96 Tears
# 1               You're The One For Me
# 2                      Play The Blues
# 3                   The Soul Of Spain
# 4     10 CC's Greatest Hits 1972-1978
# ...                               ...
# 3626                          Romance
# 3627          Classics By Candlelight
# 3628                     Alte Märsche
# 3629               The Best Of ZZ Top
# 3630                           Камино
#
#                                                Artist      Type  \
# 0                  ? (Question Mark) & The Mysterians  Vinyl 45
# 1                                           "D" Train  Vinyl 33
# 2                                         101 Strings  Vinyl 33
# 3                                         101 Strings  Vinyl 33
# 4                                                10cc  Vinyl 33
# ...                                               ...       ...
# 3626                                           Zamfir  Vinyl 33
# 3627                      Zamfir / van Hoof Orchestra  Vinyl 33
# 3628  Zentrales Orchester Des Ministeriums Des Innern  Vinyl 33
# 3629                                           ZZ Top  Vinyl 33
# 3630                                     Лили Иванова  Vinyl 33
#
#                Genre  Released   Country                      Label
# 0               Rock      1966   Germany                     Ariola
# 1              Disco      1988    Canada            Prelude Records
# 2              Blues      1958       USA  Pye Golden Guinea Records
# 3          Classical      1959        UK  Pye Golden Guinea Records
# 4           Art Rock      1979    Greece                    Mercury
# ...              ...       ...       ...                        ...
# 3626  Easy Listening      1982    Greece                    Philips
# 3627  Easy Listening      1980        UK                    Philips
# 3628         Marches      1966       GDR                     ETERNA
# 3629      Blues Rock      1977    Greece                Warner Bros
# 3630        Schlager      1969  Bulgaria                  Балкантон
#
# [3631 rows x 7 columns]

# %% [markdown]
# ## Export to excel file

# %%
df.to_excel('clean_data.xlsx', index=False)
