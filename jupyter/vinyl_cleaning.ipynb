# %% [markdown]
# ### Merge and clean datasets

# %%
import pandas as pd

# %% [markdown]
# #### Load the dataframes

# %%
def load_data():
    data = pd.read_excel('data.xlsx')
    return data

# %%
df = load_data()

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Drop unused columns and replace NAs

# %%
df.drop('CAT#', axis=1 , inplace=True)
df.drop(list(df.filter(regex = 'Unnamed')), axis = 1, inplace = True)

# %%
def trim_all_columns(df):
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)
cols = [ 'Title','Artist','Type','Genre','Released', 'Country','Label']
df = trim_all_columns(df).reindex(columns=cols)

# %%
df['Released'] = df['Released'].fillna(0).astype(int)

# %%
df
# Out:
#                                 Title  \
# 0                            96 Tears
# 1               You're The One For Me
# 2                      Play The Blues
# 3                   The Soul Of Spain
# 4     10 CC's Greatest Hits 1972-1978
# ...                               ...
# 3586                          Romance
# 3587          Classics By Candlelight
# 3588                     Alte Märsche
# 3589               The Best Of ZZ Top
# 3590                           Камино
#
#                                                Artist      Type  \
# 0                  ? (Question Mark) & The Mysterians  Vinyl 45
# 1                                           "D" Train  Vinyl 33
# 2                                         101 Strings  Vinyl 33
# 3                                         101 Strings  Vinyl 33
# 4                                                10cc  Vinyl 33
# ...                                               ...       ...
# 3586                                           Zamfir  Vinyl 33
# 3587                      Zamfir / van Hoof Orchestra  Vinyl 33
# 3588  Zentrales Orchester Des Ministeriums Des Innern  Vinyl 33
# 3589                                           ZZ Top  Vinyl 33
# 3590                                     Лили Иванова  Vinyl 33
#
#                Genre  Released   Country                      Label
# 0               Rock      1966   Germany                     Ariola
# 1              Disco      1988    Canada            Prelude Records
# 2              Blues      1958       USA  Pye Golden Guinea Records
# 3          Classical      1959        UK  Pye Golden Guinea Records
# 4           Art Rock      1979    Greece                    Mercury
# ...              ...       ...       ...                        ...
# 3586  Easy Listening      1982    Greece                    Philips
# 3587  Easy Listening      1980        UK                    Philips
# 3588         Marches      1966       GDR                     ETERNA
# 3589      Blues Rock      1977    Greece                Warner Bros
# 3590        Schlager      1969  Bulgaria                  Балкантон
#
# [3591 rows x 7 columns]

# %%
df.head()
# Out:
#                              Title                              Artist  \
# 0                         96 Tears  ? (Question Mark) & The Mysterians
# 1            You're The One For Me                           "D" Train
# 2                   Play The Blues                         101 Strings
# 3                The Soul Of Spain                         101 Strings
# 4  10 CC's Greatest Hits 1972-1978                                10cc
#
#        Type      Genre  Released  Country                      Label
# 0  Vinyl 45       Rock      1966  Germany                     Ariola
# 1  Vinyl 33      Disco      1988   Canada            Prelude Records
# 2  Vinyl 33      Blues      1958      USA  Pye Golden Guinea Records
# 3  Vinyl 33  Classical      1959       UK  Pye Golden Guinea Records
# 4  Vinyl 33   Art Rock      1979   Greece                    Mercury

# %%
df.shape
# Out:
# (3591, 7)

# %% [markdown]
# #### Check for duplicated rows and drop

# %%
df.duplicated(subset=['Title','Artist', 'Genre', 'Released', 'Country',
 'Label','Type']).sum()
# Out:
# 3

# %%
dups = df.loc[df.duplicated(subset=['Title','Artist', 'Genre',
                                           'Released', 'Country',
                                           'Label','Type'],keep=False), :]

# %%
dups
# Out:
#                                Title         Artist      Type      Genre  \
# 1438  Mad, Bad And Dangerous To Know  Dead Or Alive  Vinyl 33  Synth-pop
# 1439  Mad, Bad And Dangerous To Know  Dead Or Alive  Vinyl 33  Synth-pop
# 1440                 Out Of The Blue  Debbie Gibson  Vinyl 33  Synth-pop
# 1441                 Out Of The Blue  Debbie Gibson  Vinyl 33  Synth-pop
# 3242           Η Ελλάδα Τραγουδάει..        Various  Vinyl 33       Folk
# 3243           Η Ελλάδα Τραγουδάει..        Various  Vinyl 33       Folk
#
#       Released Country     Label
# 1438      1986  Greece      Epic
# 1439      1986  Greece      Epic
# 1440      1987  Greece  Atlantic
# 1441      1987  Greece  Atlantic
# 3242      1979  Greece  Columbia
# 3243      1979  Greece  Columbia

# %% [markdown]
# > keep duplicates to certify errors

# %%
df.drop_duplicates(subset=['Title','Artist', 'Genre',
                                  'Released', 'Country',
                                  'Label','Type'], keep='first', inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.shape
# Out:
# (3588, 7)

# %%
df
# Out:
#                                 Title  \
# 0                            96 Tears
# 1               You're The One For Me
# 2                      Play The Blues
# 3                   The Soul Of Spain
# 4     10 CC's Greatest Hits 1972-1978
# ...                               ...
# 3583                          Romance
# 3584          Classics By Candlelight
# 3585                     Alte Märsche
# 3586               The Best Of ZZ Top
# 3587                           Камино
#
#                                                Artist      Type  \
# 0                  ? (Question Mark) & The Mysterians  Vinyl 45
# 1                                           "D" Train  Vinyl 33
# 2                                         101 Strings  Vinyl 33
# 3                                         101 Strings  Vinyl 33
# 4                                                10cc  Vinyl 33
# ...                                               ...       ...
# 3583                                           Zamfir  Vinyl 33
# 3584                      Zamfir / van Hoof Orchestra  Vinyl 33
# 3585  Zentrales Orchester Des Ministeriums Des Innern  Vinyl 33
# 3586                                           ZZ Top  Vinyl 33
# 3587                                     Лили Иванова  Vinyl 33
#
#                Genre  Released   Country                      Label
# 0               Rock      1966   Germany                     Ariola
# 1              Disco      1988    Canada            Prelude Records
# 2              Blues      1958       USA  Pye Golden Guinea Records
# 3          Classical      1959        UK  Pye Golden Guinea Records
# 4           Art Rock      1979    Greece                    Mercury
# ...              ...       ...       ...                        ...
# 3583  Easy Listening      1982    Greece                    Philips
# 3584  Easy Listening      1980        UK                    Philips
# 3585         Marches      1966       GDR                     ETERNA
# 3586      Blues Rock      1977    Greece                Warner Bros
# 3587        Schlager      1969  Bulgaria                  Балкантон
#
# [3588 rows x 7 columns]

# %% [markdown]
# ## Export to excel file

# %%
df.to_excel('clean_data.xlsx', index=False)
